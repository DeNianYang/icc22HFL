# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
plt.rcParams["mathtext.fontset"] = "cm"

# %%
def convert_txt_to_np(line):
    convert_np = []
    tmp = ''
    for i in line:
        if i != '\n':
            tmp += i
        else:
            convert_np.append(float(tmp))
            tmp = ''
    return np.array(convert_np)

# %%
from IPython.display import HTML, display

def set_background(color):    
    script = (
        "var cell = this.closest('.jp-CodeCell');"
        "var editor = cell.querySelector('.jp-Editor');"
        "editor.style.background='{}';"
        "this.parentNode.removeChild(this)"
    ).format(color)

    display(HTML('<img src onerror="{}">'.format(script)))

# %%
xlabel_fontsize = 30
ylabel_fontsize = 30
xticks_fontsize = 26
yticks_fontsize = 26

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.lines as mlines
plt.rcParams["mathtext.fontset"] = "cm"

xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('fmnist_phy/4r0.8/accuracy.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('fmnist_phy/4r0.5/accuracy.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('fmnist_phy/4r0.3/accuracy.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()

with open('fmnist_phy/4r0.8/time_sum.txt', 'r') as a:
    g1 = a.read()
    g1 = convert_txt_to_np(g1)
    a.close()
with open('fmnist_phy/4r0.5/time_sum.txt', 'r') as a:
    g2 = a.read()
    g2 = convert_txt_to_np(g2)
    a.close()
with open('fmnist_phy/4r0.3/time_sum.txt', 'r') as a:
    g3 = a.read()
    g3 = convert_txt_to_np(g3)
    a.close()
###############################################################
with open('fmnist_phy/phy0.8/accuracy.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('fmnist_phy/phy0.5/accuracy.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('fmnist_phy/phy0.3/accuracy.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()
    
with open('fmnist_phy/phy0.8/time_sum.txt', 'r') as a:
    g4 = a.read()
    g4 = convert_txt_to_np(g4)
    a.close()
with open('fmnist_phy/phy0.5/time_sum.txt', 'r') as a:
    g5 = a.read()
    g5 = convert_txt_to_np(g5)
    a.close()
with open('fmnist_phy/phy0.3/time_sum.txt', 'r') as a:
    g6 = a.read()
    g6 = convert_txt_to_np(g6)
    a.close()
###############################################################
with open('fmnist_phy/rl0.8/accuracy.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('fmnist_phy/rl0.5/accuracy.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('fmnist_phy/rl0.3/accuracy.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()
    
with open('fmnist_phy/rl0.8/time_sum.txt', 'r') as a:
    g7 = a.read()
    g7 = convert_txt_to_np(g7)
    a.close()
with open('fmnist_phy/rl0.5/time_sum.txt', 'r') as a:
    g8 = a.read()
    g8 = convert_txt_to_np(g8)
    a.close()
with open('fmnist_phy/rl0.3/time_sum.txt', 'r') as a:
    g9 = a.read()
    g9 = convert_txt_to_np(g9)
    a.close()
###############################################################
set_background('rgba(100,0,900,0.3)')
fig, ax = plt.subplots(figsize=(10, 11), dpi=72)

plt.plot(g1, r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g2, r2, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g3, r3, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g4, r4, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g5, r5, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g6, r6, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g7, r7, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g8, r8, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g9, r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='TA(4,0), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='TA(4,0), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='TA(4,0), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

plt.ylim(0.7, 0.87)
plt.yticks(np.arange(0.7, 0.871, (0.87-0.7)/5))
leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.21), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)
plt.xlim(0, 900)
plt.xticks(np.arange(0, 901, 150))

plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")



plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Time', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/Fashion_physical_accuracy.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/Fashion_physical_accuracy.png"
plt.savefig(loc)
loc = "Figure/Fashion_physical_accuracy.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.lines as mlines
plt.rcParams["mathtext.fontset"] = "cm"

xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('fmnist_phy/4r0.8/loss.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('fmnist_phy/4r0.5/loss.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('fmnist_phy/4r0.3/loss.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()

with open('fmnist_phy/4r0.8/time_sum.txt', 'r') as a:
    g1 = a.read()
    g1 = convert_txt_to_np(g1)
    a.close()
with open('fmnist_phy/4r0.5/time_sum.txt', 'r') as a:
    g2 = a.read()
    g2 = convert_txt_to_np(g2)
    a.close()
with open('fmnist_phy/4r0.3/time_sum.txt', 'r') as a:
    g3 = a.read()
    g3 = convert_txt_to_np(g3)
    a.close()
###############################################################
with open('fmnist_phy/phy0.8/loss.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('fmnist_phy/phy0.5/loss.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('fmnist_phy/phy0.3/loss.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()
    
with open('fmnist_phy/phy0.8/time_sum.txt', 'r') as a:
    g4 = a.read()
    g4 = convert_txt_to_np(g4)
    a.close()
with open('fmnist_phy/phy0.5/time_sum.txt', 'r') as a:
    g5 = a.read()
    g5 = convert_txt_to_np(g5)
    a.close()
with open('fmnist_phy/phy0.3/time_sum.txt', 'r') as a:
    g6 = a.read()
    g6 = convert_txt_to_np(g6)
    a.close()
###############################################################
with open('fmnist_phy/rl0.8/loss.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('fmnist_phy/rl0.5/loss.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('fmnist_phy/rl0.3/loss.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()
    
with open('fmnist_phy/rl0.8/time_sum.txt', 'r') as a:
    g7 = a.read()
    g7 = convert_txt_to_np(g7)
    a.close()
with open('fmnist_phy/rl0.5/time_sum.txt', 'r') as a:
    g8 = a.read()
    g8 = convert_txt_to_np(g8)
    a.close()
with open('fmnist_phy/rl0.3/time_sum.txt', 'r') as a:
    g9 = a.read()
    g9 = convert_txt_to_np(g9)
    a.close()
###############################################################
set_background('rgba(100,0,900,0.3)')
fig, ax = plt.subplots(figsize=(10, 11.25), dpi=72)

plt.plot(g1, r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g2, r2, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g3, r3, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g4, r4, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g5, r5, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g6, r6, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g7, r7, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g8, r8, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g9, r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='TA(4,0), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='TA(4,0), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='TA(4,0), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

plt.ylim(0.07, 0.2)
plt.yticks(np.arange(0.07, 0.21, (0.21-0.07)/5))
leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.78), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)
plt.xlim(0, 900)
plt.xticks(np.arange(0, 901, 150))

plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Loss', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Time', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/Fashion_physical_loss.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/Fashion_physical_loss.png"
plt.savefig(loc)
loc = "Figure/Fashion_physical_loss.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.lines as mlines
plt.rcParams["mathtext.fontset"] = "cm"

xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('cifar_phy/4r0.8/accuracy.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('cifar_phy/4r0.5/accuracy.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_phy/4r0.3/accuracy.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()

with open('cifar_phy/4r0.8/time_sum.txt', 'r') as a:
    g1 = a.read()
    g1 = convert_txt_to_np(g1)
    a.close()
with open('cifar_phy/4r0.5/time_sum.txt', 'r') as a:
    g2 = a.read()
    g2 = convert_txt_to_np(g2)
    a.close()
with open('cifar_phy/4r0.3/time_sum.txt', 'r') as a:
    g3 = a.read()
    g3 = convert_txt_to_np(g3)
    a.close()
###############################################################
with open('cifar_phy/phy0.8/accuracy.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_phy/phy0.5/accuracy.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('cifar_phy/phy0.3/accuracy.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()
    
with open('cifar_phy/phy0.8/time_sum.txt', 'r') as a:
    g4 = a.read()
    g4 = convert_txt_to_np(g4)
    a.close()
with open('cifar_phy/phy0.5/time_sum.txt', 'r') as a:
    g5 = a.read()
    g5 = convert_txt_to_np(g5)
    a.close()
with open('cifar_phy/phy0.3/time_sum.txt', 'r') as a:
    g6 = a.read()
    g6 = convert_txt_to_np(g6)
    a.close()
###############################################################
with open('cifar_phy/rl0.8/accuracy.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('cifar_phy/rl0.5/accuracy.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('cifar_phy/rl0.3/accuracy.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()
    
with open('cifar_phy/rl0.8/time_sum.txt', 'r') as a:
    g7 = a.read()
    g7 = convert_txt_to_np(g7)
    a.close()
with open('cifar_phy/rl0.5/time_sum.txt', 'r') as a:
    g8 = a.read()
    g8 = convert_txt_to_np(g8)
    a.close()
with open('cifar_phy/rl0.3/time_sum.txt', 'r') as a:
    g9 = a.read()
    g9 = convert_txt_to_np(g9)
    a.close()
###############################################################
set_background('rgba(100,0,900,0.3)')
fig, ax = plt.subplots(figsize=(10, 11), dpi=72)

plt.plot(g1, r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g2, r2, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g3, r3, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g4, r4, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g5, r5, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g6, r6, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g7, r7, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g8, r8, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g9, r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='TA(4,0), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='TA(4,0), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='TA(4,0), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

plt.ylim(0.2, 0.55)
plt.yticks(np.arange(0.2, 0.551, (0.55-0.2)/5))
leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.21), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)
plt.xlim(0, 900)
plt.xticks(np.arange(0, 901, 150))

plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")



plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Time', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/Cifar_physical_accuracy.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/Cifar_physical_accuracy.png"
plt.savefig(loc)
loc = "Figure/Cifar_physical_accuracy.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.lines as mlines
plt.rcParams["mathtext.fontset"] = "cm"

xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('cifar_phy/4r0.8/loss.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('cifar_phy/4r0.5/loss.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_phy/4r0.3/loss.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()

with open('cifar_phy/4r0.8/time_sum.txt', 'r') as a:
    g1 = a.read()
    g1 = convert_txt_to_np(g1)
    a.close()
with open('cifar_phy/4r0.5/time_sum.txt', 'r') as a:
    g2 = a.read()
    g2 = convert_txt_to_np(g2)
    a.close()
with open('cifar_phy/4r0.3/time_sum.txt', 'r') as a:
    g3 = a.read()
    g3 = convert_txt_to_np(g3)
    a.close()
###############################################################
with open('cifar_phy/phy0.8/loss.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_phy/phy0.5/loss.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('cifar_phy/phy0.3/loss.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()
    
with open('cifar_phy/phy0.8/time_sum.txt', 'r') as a:
    g4 = a.read()
    g4 = convert_txt_to_np(g4)
    a.close()
with open('cifar_phy/phy0.5/time_sum.txt', 'r') as a:
    g5 = a.read()
    g5 = convert_txt_to_np(g5)
    a.close()
with open('cifar_phy/phy0.3/time_sum.txt', 'r') as a:
    g6 = a.read()
    g6 = convert_txt_to_np(g6)
    a.close()
###############################################################
with open('cifar_phy/rl0.8/loss.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('cifar_phy/rl0.5/loss.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('cifar_phy/rl0.3/loss.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()
    
with open('cifar_phy/rl0.8/time_sum.txt', 'r') as a:
    g7 = a.read()
    g7 = convert_txt_to_np(g7)
    a.close()
with open('cifar_phy/rl0.5/time_sum.txt', 'r') as a:
    g8 = a.read()
    g8 = convert_txt_to_np(g8)
    a.close()
with open('cifar_phy/rl0.3/time_sum.txt', 'r') as a:
    g9 = a.read()
    g9 = convert_txt_to_np(g9)
    a.close()
###############################################################
set_background('rgba(100,0,900,0.3)')
fig, ax = plt.subplots(figsize=(10, 11.25), dpi=72)

plt.plot(g1, r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g2, r2, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g3, r3, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g4, r4, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g5, r5, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g6, r6, color='#008800', lw=3, label='TA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(g7, r7, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(g8, r8, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(g9, r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='TA(4,0), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='TA(4,0), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='TA(4,0), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

plt.ylim(0.2, 0.501)
plt.yticks(np.arange(0.2, 0.501, (0.51-0.2)/5))
leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.78), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)
plt.xlim(0, 900)
plt.xticks(np.arange(0, 901, 150))

plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Loss', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Time', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/Cifar_physical_loss.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/Cifar_physical_loss.png"
plt.savefig(loc)
loc = "Figure/Cifar_physical_loss.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
xlabel_fontsize = 30
ylabel_fontsize = 30
xticks_fontsize = 26
yticks_fontsize = 26

# %%
with open('HT IID graph/HT32.txt', 'r') as a:
    t = a.read()
    n0 = convert_txt_to_np(t)
    a.close()
with open('HT IID graph/HT44.txt', 'r') as a:
    t = a.read()
    n1 = convert_txt_to_np(t)
    a.close()
with open('HT IID graph/HT18.txt', 'r') as a:
    t = a.read()
    n3 = convert_txt_to_np(t)
    a.close()
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(n0, color='#0000FF', lw=2, label='Topo.1', linestyle='-.', markerfacecolor='none')
plt.plot(n1, color='#00AF00', lw=2, label='Topo.2', linestyle='-.', markerfacecolor='none')
plt.plot(n3, color='#FF0000', lw=2, label='Topo.3', linestyle='-.', markerfacecolor='none')
# plt.plot(device_12DP['total_acc'], color='#AFAF00', lw=2, label='DP = 12', linestyle='-', markerfacecolor='none')
# plt.plot(device_15DP['total_acc'], color='#AF0000', lw=2, label='DP = 15', linestyle='-', markerfacecolor='none')

leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)

plt.xlim(50, 300)
plt.xticks(np.arange(0, 301, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.7, 0.9)
plt.yticks(np.arange(0.7, 0.91, (0.9-0.7)/4))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/reg_accuracy.pdf"
plt.savefig(loc)
loc = "Figure/reg_accuracy.png"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/reg_accuracy.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(no_select, color='#0000AF', lw=2, label='Baseline', linestyle='-', markerfacecolor='none')
plt.plot(select, color='#00AF00', lw=2, label='Neighbor selection', linestyle='-', markerfacecolor='none')

leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.1), prop={'size': '21', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=5,facecolor='None')
leg.get_frame().set_linewidth(0.0)

plt.xlim(0, 300)
plt.xticks(np.arange(0, 300, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.ylim(0.4, 0.9)
plt.yticks(np.arange(0.4, 0.9, (0.9-0.4)/5))

ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

y1 = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
y2 = ['0.4', '0.5', '0.6', '0.7', '0.8', '0.9']
plt.yticks(y1,y2)

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/select_vs_noselect_accuracy.pdf"
plt.savefig(loc)
loc = "Figure/select_vs_noselect_accuracy.png"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('45node different regualr/2.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('45node different regualr/4.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('45node different regualr/8.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('45node different regualr/16.txt', 'r') as a:
    r16 = a.read()
    r16 = convert_txt_to_np(r16)
    a.close()

with open('45node different regualr/2c.txt', 'r') as a:
    c2 = a.read()
    c2 = convert_txt_to_np(c2)
    a.close()
with open('45node different regualr/4c.txt', 'r') as a:
    c4 = a.read()
    c4 = convert_txt_to_np(c4)
    a.close()
with open('45node different regualr/8c.txt', 'r') as a:
    c8 = a.read()
    c8 = convert_txt_to_np(c8)
    a.close()
with open('45node different regualr/16c.txt', 'r') as a:
    c16 = a.read()
    c16 = convert_txt_to_np(c16)
    a.close()
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(8, 4), dpi=72)

xlabel_fontsize = 19
ylabel_fontsize = 19
xticks_fontsize = 16
yticks_fontsize = 16
plt.plot(r2, color='#000000', lw=1.3, label='2-regular', linestyle='-', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=1.3, label='4-regular', linestyle='-', markerfacecolor='none')
plt.plot(r8, color='#FF0000', lw=1.3, label='8-regular', linestyle='-', markerfacecolor='none')
plt.plot(r16, color='#00AF00', lw=1.3, label='16-regular', linestyle='-', markerfacecolor='none')

leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.34), prop={'size': '17', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=4,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.legend(loc=2,prop={'size': '15', 'family': 'Times New Roman'})
# plt.grid(linestyle='-.')
plt.xlim(0, 500)
plt.xticks(np.arange(0, 501, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.6, 0.9)
plt.yticks(np.arange(0.6, 0.91, (0.9-0.6)/4))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
ax2 = ax.twinx()
ax2.plot(c2, color='#000000', lw=1.3, label='2-NO     ', linestyle='--', markerfacecolor='none')
ax2.plot(c4, color='#0000FF', lw=1.3, label='4-NO      ', linestyle='--', markerfacecolor='none')
ax2.plot(c8, color='#FF0000', lw=1.3, label='8-NO     ', linestyle='--', markerfacecolor='none')
ax2.plot(c16, color='#00AF00', lw=1.3, label='16-NO   ', linestyle='--', markerfacecolor='none')
ax2.set_ylabel('NO (GB)', fontsize=xlabel_fontsize, family="Times New Roman")
ax2.set_ylim(0, 9.1)
ax2.set_yticks(np.arange(0, 9.1, (9-1)/4))
# plt.yscale("logit")
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")
leg2 = ax2.legend(loc=10, bbox_to_anchor=(0.485, 1.12), prop={'size': '17', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=4,facecolor='None')
leg2.get_frame().set_linewidth(0.0)
# ax2.legend(loc=4,prop={'size': '15', 'family': 'Times New Roman'})
plt.tight_layout()

loc = "Figure/different_regular.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/different_regular.png"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/different_regular.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
xlabel_fontsize = 28
ylabel_fontsize = 28
xticks_fontsize = 24
yticks_fontsize = 24
with open('IIDvsSelectandNOSelect/IID.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('IIDvsSelectandNOSelect/non-iid-noS.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('IIDvsSelectandNOSelect/non-iid-S.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
set_background('rgba(100,0,900,0.3)')
xlabel_fontsize = 28
ylabel_fontsize = 28
xticks_fontsize = 24
yticks_fontsize = 24
fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

p1 = plt.plot(r2, color='#FF0000', lw=2, label='IID', linestyle='--', markerfacecolor='none')
p2 = plt.plot(r4, color='#C79FEF', lw=2, label='non-IID R', linestyle='-.', markerfacecolor='none')
p3 = plt.plot(r8, color='#15B01A', lw=2, label='non-IID CBA(2,0)', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.15), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=2,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 450)
plt.xticks(np.arange(0, 450, 100))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.1, 0.9)
plt.yticks(np.arange(0.1, 1, (1-0.1)/6))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/IIDvsSelectandNOSelect.pdf"
plt.savefig(loc)
loc = "Figure/IIDvsSelectandNOSelect.png"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/IIDvsSelectandNOSelect.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/0.8/accuracy/4r0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.8/accuracy/calgo0.8.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.8/accuracy/rl0.8.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(30, 300)
plt.xticks(np.arange(30, 300, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.7, 0.85)
plt.yticks(np.arange(0.7, 0.851, (0.85-0.7)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_accuracy_0.8.pdf"
plt.savefig(loc)
loc = "Figure/fashion_accuracy_0.8.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/0.8/loss/4r0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.8/loss/calgo0.8.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.8/loss/rl0.8.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 300)
plt.xticks(np.arange(0, 300, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.06, 0.3)
plt.yticks(np.arange(0.06, 0.31, (0.3-0)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_loss_0.8.pdf"
plt.savefig(loc)
loc = "Figure/fashion_loss_0.8.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/0.5/accuracy/4r0.5.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.5/accuracy/calgo0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.5/accuracy/rl0.5.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 200)
plt.xticks(np.arange(0, 200, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.7, 0.86)
plt.yticks(np.arange(0.7, 0.861, (0.86-0.7)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_accuracy_0.5.pdf"
plt.savefig(loc)
loc = "Figure/fashion_accuracy_0.5.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/0.5/loss/4r0.5.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.5/loss/calgo0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.5/loss/rl0.5.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 200)
plt.xticks(np.arange(0, 200, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.1, 0.3)
plt.yticks(np.arange(0.1, 0.31, (0.3-0.1)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_loss_0.5.pdf"
plt.savefig(loc)
loc = "Figure/fashion_loss_0.5.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/random/accuracy/calgoran.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/random/accuracy/rlran.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r4, color='#0000FF', lw=2, label='CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='Hybrid', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 250)
plt.xticks(np.arange(0, 250, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.7, 0.86)
plt.yticks(np.arange(0.7, 0.861, (0.86-0.7)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_accuracy_random.pdf"
plt.savefig(loc)
loc = "Figure/fashion_accuracy_random.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/random/loss/calgoran.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/random/loss/rlran.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

# plt.plot(r2, color='#FF0000', lw=2, label='Regular', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='Hybrid', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '21', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 250)
plt.xticks(np.arange(0, 250, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.08, 0.3)
plt.yticks(np.arange(0.08, 0.31, (0.3-0.1)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_loss_random.pdf"
plt.savefig(loc)
loc = "Figure/fashion_loss_random.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar0.8/accuracy/4r0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/accuracy/calgo0.8.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/accuracy/rl0.8.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 330)
plt.xticks(np.arange(0, 330, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.25, 0.45)
plt.yticks(np.arange(0.25, 0.5, (0.5-0.25)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_accuracy_0.8.pdf"
plt.savefig(loc)
loc = "Figure/cifar_accuracy_0.8.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar0.8/loss/4r0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/loss/calgo0.8.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/loss/rl0.8.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 330)
plt.xticks(np.arange(0, 330, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.20, 0.4)
plt.yticks(np.arange(0.20, 0.44, (0.44-0.20)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_loss_0.8.pdf"
plt.savefig(loc)
loc = "Figure/cifat_loss_0.8.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar0.5_good_case/accuracy/4r0.5.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/accuracy/calgo0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/accuracy/rl0.5.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 220)
plt.xticks(np.arange(0, 220, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.43, 0.55)
plt.yticks(np.arange(0.43, 0.551, (0.55-0.43)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_accuracy_0.5.pdf"
plt.savefig(loc)
loc = "Figure/cifar_accuracy_0.5.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar0.5_good_case/loss/4r0.5.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/loss/calgo0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/loss/rl0.5.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 220)
plt.xticks(np.arange(0, 220, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.25, 0.4)
plt.yticks(np.arange(0.25, 0.44, (0.44-0.25)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_loss_0.5.pdf"
plt.savefig(loc)
loc = "Figure/cifat_loss_0.5.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar_random/accuracy/calgoran.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar_random/accuracy/rlran.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r4, color='#0000FF', lw=2, label='CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='Hybrid', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 150)
plt.xticks(np.arange(0, 150, 30))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.3, 0.5)
plt.yticks(np.arange(0.3, 0.51, (0.5-0.3)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_accuracy_random.pdf"
plt.savefig(loc)
loc = "Figure/cifar_accuracy_random.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar_random/loss/calgoran.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar_random/loss/rlran.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

# plt.plot(r2, color='#FF0000', lw=2, label='Regular', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='Hybrid', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '21', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 150)
plt.xticks(np.arange(0, 150, 30))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.25, 0.4)
plt.yticks(np.arange(0.25, 0.41, (0.4-0.25)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_loss_random.pdf"
plt.savefig(loc)
loc = "Figure/cifar_loss_random.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('calgo VS regular draw graph/accuracy/4r.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('calgo VS regular draw graph/accuracy/calgo.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r4, color='#0000FF', lw=2, label='Regular', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#FF0000', lw=2, label='CBA', linestyle='--', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '21', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 330)
plt.xticks(np.arange(0, 330, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.7, 0.85)
plt.yticks(np.arange(0.7, 0.851, (0.85-0.7)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/4rVScalgo_accuracy.pdf"
plt.savefig(loc)
loc = "Figure/4rVScalgo_accuracy_random.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('calgo VS regular draw graph/loss/4r.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('calgo VS regular draw graph/loss/calgo.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

# plt.plot(r2, color='#FF0000', lw=2, label='Regular', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='Regular', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#FF0000', lw=2, label='CBA', linestyle='--', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '21', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 330)
plt.xticks(np.arange(0, 330, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.05, 0.3)
plt.yticks(np.arange(0.05, 0.31, (0.3-0.1)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/4rVScalgo_loss.pdf"
plt.savefig(loc)
loc = "Figure/4rVScalgo_loss.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/0.3/accuracy/0calgo0.3.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.3/accuracy/4calgo0.3.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.3/accuracy/rl0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 250)
plt.xticks(np.arange(0, 250, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.77, 0.87)
plt.yticks(np.arange(0.77, 0.871, (0.87-0.77)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_accuracy_0.3.pdf"
plt.savefig(loc)
loc = "Figure/fashion_accuracy_0.3.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('evaluation graph/0.3/loss/0calgo0.3.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.3/loss/4calgo0.3.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.3/loss/rl0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 250)
plt.xticks(np.arange(0, 250, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.09, 0.21)
plt.yticks(np.arange(0.09, 0.211, (0.21-0.09)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/fashion_loss_0.3.pdf"
plt.savefig(loc)
loc = "Figure/fashion_loss_0.3.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar0.3/accuracy/4r0.3.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/accuracy/calgo0.3.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/accuracy/rl0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 110)
plt.xticks(np.arange(0, 110, 30))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.45, 0.55)
plt.yticks(np.arange(0.45, 0.551, (0.55-0.45)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_accuracy_0.3.pdf"
plt.savefig(loc)
loc = "Figure/cifar_accuracy_0.3.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
with open('cifar_evaluation/s18_cifar0.3/loss/4r0.3.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/loss/calgo0.3.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/loss/rl0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()

set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r2, color='#FF0000', lw=2, label='0-CBA', linestyle='--', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=2, label='2-CBA', linestyle='-.', markerfacecolor='none')
plt.plot(r8, color='#15B01A', lw=2, label='DONES', linestyle='-', markerfacecolor='none')
# leg = plt.legend(handles=[p1,p2,p3],loc=10, bbox_to_anchor=(0.7, 0.21), \
#                  prop={'size': '32', 'family': 'Times New Roman'},\
#                  frameon='False', labelspacing=0, handletextpad=0.2,\
#                  handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '25', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)
# plt.grid(linestyle='-.')
plt.xlim(0, 110)
plt.xticks(np.arange(0, 110, 30))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.33, 0.41)
plt.yticks(np.arange(0.33, 0.411, (0.41-0.33)/5))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_loss_0.3.pdf"
plt.savefig(loc)
loc = "Figure/cifar_loss_0.3.png"
plt.savefig(loc,bbox_inches = 'tight')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
xlabel_fontsize = 28
ylabel_fontsize = 28
xticks_fontsize = 24
yticks_fontsize = 24
with open('accuracy vs HT and bias/0.txt', 'r') as a:
    r0 = a.read()
    r0 = convert_txt_to_np(r0)
    a.close()
with open('accuracy vs HT and bias/1.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('accuracy vs HT and bias/2.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('accuracy vs HT and bias/3.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()
with open('accuracy vs HT and bias/4.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(6, 4), dpi=72)

plt.plot(r0, color='#FF0000', lw=2, label='CBA(4,0)', linestyle='-', markerfacecolor='none')
plt.plot([], color='#0343DF', lw=2, label='        ', linestyle='-', markerfacecolor='none')
plt.plot(r1, color='#FFA500', lw=2, label='CBA(4,1)', linestyle='-', markerfacecolor='none')
plt.plot(r2, color='#0343DF', lw=2, label='CBA(4,2)', linestyle='-', markerfacecolor='none')

plt.plot(r3, color='#000000', lw=2, label='CBA(4,3)', linestyle='-', markerfacecolor='none')

plt.plot(r4, color='#00AF00', lw=2, label='CBA(4,4)', linestyle='-', markerfacecolor='none')

# plt.plot(device_12DP['total_acc'], color='#AFAF00', lw=2, label='DP = 12', linestyle='-', markerfacecolor='none')
# plt.plot(device_15DP['total_acc'], color='#AF0000', lw=2, label='DP = 15', linestyle='-', markerfacecolor='none')
leg._legend_box.align = "right"
leg = plt.legend(loc=10, bbox_to_anchor=(0.5, 1.12), prop={'size': '23', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=1, columnspacing=0.5, ncol=3,facecolor='None')
leg.get_frame().set_linewidth(0.0)


plt.xlim(140, 250)
plt.xticks(np.arange(140, 251, 20))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")

plt.ylim(0.8, 0.83)
plt.yticks(np.arange(0.8, 0.831, (0.83-0.8)/4))
ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/Accuracy_vs_HT_Bias.pdf"
plt.savefig(loc)
loc = "Figure/Accuracy_vs_HT_Bias.png"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/Accuracy_vs_HT_Bias.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.lines as mlines
plt.rcParams["mathtext.fontset"] = "cm"

xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('evaluation graph/0.8/accuracy/4r0.8.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('evaluation graph/0.8/accuracy/calgo0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.8/accuracy/rl0.8.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()
    
    
with open('evaluation graph/0.5/accuracy/4r0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.5/accuracy/calgo0.5.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('evaluation graph/0.5/accuracy/rl0.5.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()

    
with open('evaluation graph/0.3/accuracy/0calgo0.3.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('evaluation graph/0.3/accuracy/4calgo0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('evaluation graph/0.3/accuracy/rl0.3.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()    
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(10, 11), dpi=72)

plt.plot(r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r2, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r3, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r5, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r6, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r7, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r8, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='CBA(4,2), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='CBA(4,2), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='CBA(4,2), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.21), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)

plt.xlim(0, 300)
plt.xticks(np.arange(0, 301, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.ylim(0.7, 0.87)
plt.yticks(np.arange(0.7, 0.871, (0.87-0.7)/5))


ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")
# y1 = [0.76, 0.8, 0.84, 0.88, 0.92]
# y2 = ['0.76', '0.8', '0.84','0.88', '0.92']
# plt.yticks(y1,y2)

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/Fashion_all_accuracy.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/Fashion_all_accuracy.png"
plt.savefig(loc)
loc = "Figure/Fashion_all_accuracy.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.lines as mlines
plt.rcParams["mathtext.fontset"] = "cm"

xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('cifar_evaluation/s18_cifar0.8/accuracy/4r0.8.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/accuracy/calgo0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/accuracy/rl0.8.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()
    
    
with open('cifar_evaluation/s18_cifar0.5_good_case/accuracy/4r0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/accuracy/calgo0.5.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/accuracy/rl0.5.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()

    
with open('cifar_evaluation/s18_cifar0.3/accuracy/4r0.3.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/accuracy/calgo0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/accuracy/rl0.3.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()    
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(10, 11), dpi=72)

plt.plot(r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r2, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r3, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r5, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r6, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r7, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r8, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='CBA(4,2), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='CBA(4,2), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='CBA(4,2), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.21), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)

plt.xlim(0, 300)
plt.xticks(np.arange(0, 301, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.ylim(0.2, 0.55)
plt.yticks(np.arange(0.2, 0.551, (0.55-0.2)/5))


ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")
# y1 = [0.76, 0.8, 0.84, 0.88, 0.92]
# y2 = ['0.76', '0.8', '0.84','0.88', '0.92']
# plt.yticks(y1,y2)

plt.ylabel('Accuracy', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_all_accuracy.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/cifar_all_accuracy.png"
plt.savefig(loc)
loc = "Figure/cifar_all_accuracy.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('evaluation graph/0.8/loss/4r0.8.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('evaluation graph/0.8/loss/calgo0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('evaluation graph/0.8/loss/rl0.8.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()
    
    
with open('evaluation graph/0.5/loss/4r0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('evaluation graph/0.5/loss/calgo0.5.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('evaluation graph/0.5/loss/rl0.5.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()

    
with open('evaluation graph/0.3/loss/0calgo0.3.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('evaluation graph/0.3/loss/4calgo0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('evaluation graph/0.3/loss/rl0.3.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()    
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(10, 11.25), dpi=72)

plt.plot(r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r2, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r3, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r5, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r6, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r7, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r8, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='CBA(4,2), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='CBA(4,2), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='CBA(4,2), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.78), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)

plt.xlim(0, 300)
plt.xticks(np.arange(0, 301, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.ylim(0.07, 0.19)
plt.yticks(np.arange(0.07, 0.191, (0.19-0.05)/6))


ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")
# y1 = [0.76, 0.8, 0.84, 0.88, 0.92]
# y2 = ['0.76', '0.8', '0.84','0.88', '0.92']
# plt.yticks(y1,y2)

plt.ylabel('Loss', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/Fashion_all_loss.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/Fashion_all_loss.png"
plt.savefig(loc)
loc = "Figure/Fashion_all_loss.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.lines as mlines
plt.rcParams["mathtext.fontset"] = "cm"

xlabel_fontsize = 44
ylabel_fontsize = 44
xticks_fontsize = 40
yticks_fontsize = 40
with open('cifar_evaluation/s18_cifar0.8/loss/4r0.8.txt', 'r') as a:
    r1 = a.read()
    r1 = convert_txt_to_np(r1)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/loss/calgo0.8.txt', 'r') as a:
    r2 = a.read()
    r2 = convert_txt_to_np(r2)
    a.close()
with open('cifar_evaluation/s18_cifar0.8/loss/rl0.8.txt', 'r') as a:
    r3 = a.read()
    r3 = convert_txt_to_np(r3)
    a.close()
    
    
with open('cifar_evaluation/s18_cifar0.5_good_case/loss/4r0.5.txt', 'r') as a:
    r4 = a.read()
    r4 = convert_txt_to_np(r4)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/loss/calgo0.5.txt', 'r') as a:
    r5 = a.read()
    r5 = convert_txt_to_np(r5)
    a.close()
with open('cifar_evaluation/s18_cifar0.5_good_case/loss/rl0.5.txt', 'r') as a:
    r6 = a.read()
    r6 = convert_txt_to_np(r6)
    a.close()

    
with open('cifar_evaluation/s18_cifar0.3/loss/4r0.3.txt', 'r') as a:
    r7 = a.read()
    r7 = convert_txt_to_np(r7)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/loss/calgo0.3.txt', 'r') as a:
    r8 = a.read()
    r8 = convert_txt_to_np(r8)
    a.close()
with open('cifar_evaluation/s18_cifar0.3/loss/rl0.3.txt', 'r') as a:
    r9 = a.read()
    r9 = convert_txt_to_np(r9)
    a.close()    
set_background('rgba(100,0,900,0.3)')

fig, ax = plt.subplots(figsize=(10, 11.25), dpi=72)

plt.plot(r1, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r2, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r3, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.8', linestyle=':', markerfacecolor='none')
plt.plot(r4, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r5, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r6, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.5', linestyle='--', markerfacecolor='none')
plt.plot(r7, color='#0000FF', lw=3, label='CBA(4,0), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r8, color='#008800', lw=3, label='CBA(4,2), $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')
plt.plot(r9, color='#FF0000', lw=3, label='DeepSelect, $\sigma$ = 0.3', linestyle='-', markerfacecolor='none')


blue_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle=':',markersize=15, label='CBA(4,0), $\sigma$ = 0.8')
blue_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle=':',markersize=15, label='CBA(4,2), $\sigma$ = 0.8')
blue_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle=':',markersize=15, label='DeepSelect, $\sigma$ = 0.8')
green_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='--',markersize=15, label='CBA(4,0), $\sigma$ = 0.5')
green_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='--',markersize=15, label='CBA(4,2), $\sigma$ = 0.5')
green_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='--',markersize=15, label='DeepSelect, $\sigma$ = 0.5')
red_line_1 = mlines.Line2D([], [], lw=3, color='#0000FF', linestyle='-',markersize=15, label='CBA(4,0), $\sigma$ = 0.3')
red_line_2 = mlines.Line2D([], [], lw=3, color='#008800', linestyle='-',markersize=15, label='CBA(4,2), $\sigma$ = 0.3')
red_line_3 = mlines.Line2D([], [], lw=3, color='#FF0000', linestyle='-',markersize=15, label='DeepSelect, $\sigma$ = 0.3')
line_list = [blue_line_1, green_line_1, red_line_1, blue_line_2, green_line_2, red_line_2, blue_line_3, green_line_3, red_line_3]

leg = plt.legend(handles=line_list,loc=10, bbox_to_anchor=(0.7, 0.78), prop={'size': '32', 'family': 'Times New Roman'},frameon='False', labelspacing=0, handletextpad=0.2, handlelength=0.9, columnspacing=1, ncol=1,facecolor='None')
leg.get_frame().set_linewidth(0.0)

plt.xlim(0, 300)
plt.xticks(np.arange(0, 301, 50))
plt.xticks(fontsize=xticks_fontsize, family="Times New Roman")
plt.ylim(0.2,0.5)
plt.yticks(np.arange(0.2, 0.51, (0.5-0.2)/5))


ymajorFormatter = ticker.FormatStrFormatter('%3.2f') #设置y轴标签文本的格式
ax.yaxis.set_major_formatter(ymajorFormatter)
plt.yticks(fontsize=yticks_fontsize, family="Times New Roman")
# y1 = [0.76, 0.8, 0.84, 0.88, 0.92]
# y2 = ['0.76', '0.8', '0.84','0.88', '0.92']
# plt.yticks(y1,y2)

plt.ylabel('Loss', fontsize=xlabel_fontsize, family="Times New Roman")
plt.xlabel('Rounds', fontsize=ylabel_fontsize, family="Times New Roman")
plt.tight_layout()

loc = "Figure/cifar_all_loss.pdf"
plt.savefig(loc,bbox_inches = 'tight')
loc = "Figure/cifar_all_loss.png"
plt.savefig(loc)
loc = "Figure/cifar_all_loss.eps"
plt.savefig(loc)
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='rgba(100,0,900,0.3)';this.parentNode.removeChild(this)">
